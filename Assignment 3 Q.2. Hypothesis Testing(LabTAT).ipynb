# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("LabTAT.csv")

# %%
df.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
df.shape
# Out:
# (120, 4)

# %%
df.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
L1 = data['Laboratory 1'].mean()
print('Laboratory 1 mean =',L1)
# Out:
# Laboratory 1 mean = 178.36158333333339

# %%
L2 = data['Laboratory 2'].mean()
print('Laboratory 2 mean =',L2)
# Out:
# Laboratory 2 mean = 178.9029166666668

# %%
L3 = data['Laboratory 3'].mean()
print('Laboratory 3 mean =',L3)
# Out:
# Laboratory 3 mean = 199.91325000000003

# %%
L4 = data['Laboratory 4'].mean()
print('Laboratory 4 mean =',L4)
# Out:
# Laboratory 4 mean = 163.6827499999999

# %%
print('Laboratory_1 > Laboratory_2 = ',L1 > L2)
print('Laboratory_2 > Laboratory_3 = ',L2 > L3)
print('Laboratory_3 > Laboratory_4 = ',L3 > L4)
print('Laboratory_4 > Laboratory_1 = ',L4 > L1)
# Out:
# Laboratory_1 > Laboratory_2 =  False
# Laboratory_2 > Laboratory_3 =  False
# Laboratory_3 > Laboratory_4 =  True
# Laboratory_4 > Laboratory_1 =  False

# %%
# Visualization

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(data['Laboratory 1'])
sns.distplot(data['Laboratory 2'])
sns.distplot(data['Laboratory 3'])
sns.distplot(data['Laboratory 4'])
# Out:
# <AxesSubplot:xlabel='Laboratory 4', ylabel='Density'>

# %%
sns.distplot(data['Laboratory 1'])
# Out:
# <AxesSubplot:xlabel='Laboratory 1', ylabel='Density'>

# %%
sns.distplot(data['Laboratory 2'])
# Out:
# <AxesSubplot:xlabel='Laboratory 2', ylabel='Density'>

# %%
sns.distplot(data['Laboratory 3'])
# Out:
# <AxesSubplot:xlabel='Laboratory 3', ylabel='Density'>

# %%
sns.distplot(data['Laboratory 4'])
# Out:
# <AxesSubplot:xlabel='Laboratory 4', ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=[data['Laboratory 1'],data['Laboratory 2'],data['Laboratory 3'],data['Laboratory 4']])
# Out:
# <AxesSubplot:>

# %%
#Hypothesis Testing

# %%
alpha=0.05

# %%
Lab1=pd.DataFrame(data['Laboratory 1'])
Lab2=pd.DataFrame(data['Laboratory 2'])
Lab3=pd.DataFrame(data['Laboratory 3'])
Lab4=pd.DataFrame(data['Laboratory 4'])

# %%
print(Lab1,Lab2,Lab3,Lab4)
# Out:
#      Laboratory 1
# 0          185.35
# 1          170.49
# 2          192.77
# 3          177.33
# 4          193.41
# ..            ...
# 115        178.49
# 116        176.08
# 117        202.48
# 118        182.40
# 119        182.09
#
# [120 rows x 1 columns]      Laboratory 2
# 0          165.53
# 1          185.91
# 2          194.92
# 3          183.00
# 4          169.57
# ..            ...
# 115        170.66
# 116        183.98
# 117        174.54
# 118        197.18
# 119        215.17
#
# [120 rows x 1 columns]      Laboratory 3
# 0          176.70
# 1          198.45
# 2          201.23
# 3          199.61
# 4          204.63
# ..            ...
# 115        193.80
# 116        215.25
# 117        203.99
# 118        194.52
# 119        221.49
#
# [120 rows x 1 columns]      Laboratory 4
# 0          166.13
# 1          160.79
# 2          185.18
# 3          176.42
# 4          152.60
# ..            ...
# 115        172.68
# 116        177.64
# 117        170.27
# 118        150.87
# 119        162.21
#
# [120 rows x 1 columns]

# %%
tStat, pvalue = sp.stats.f_oneway(Lab1,Lab2,Lab3,Lab4)

# %%
print("P-Value:{0} T-Statistic:{1}".format(pvalue,tStat))
# Out:
# P-Value:[2.11567089e-57] T-Statistic:[118.70421654]

# %%
if pvalue < 0.05:
  print('we reject null hypothesis')
else:
  print('we accept null hypothesis')
# Out:
# we reject null hypothesis

# %%
#There is no significant difference in the average TAT for all the labs.
